# %%
score = int(input("Enter the score :"))

if score < 40:
    band = "Support"
elif score < 70:
    band = "Developing"
elif score < 90:
    band = "Strong"
else:
    band = "Excellent"

print("Output Band:", band)
# Out:
# Enter the score : 38
# Output Band: Support

# %%
score = int(input("Enter the score :"))

if score < 40:
    band = "Support"
elif score < 70:
    band = "Developing"
elif score < 90:
    band = "Strong"
else:
    band = "Excellent"

print("Output Band:", band)
# Out:
# Enter the score : 62
# Output Band: Developing

# %%
score = int(input("Enter the score :"))

if score < 40:
    band = "Support"
elif score < 70:
    band = "Developing"
elif score < 90:
    band = "Strong"
else:
    band = "Excellent"

print("Output Band:", band)
# Out:
# Enter the score : 81
# Output Band: Strong

# %% [markdown]
# score = int(input("Enter the score :"))
#
# if score < 40:
#     band = "Support"
# elif score < 70:
#     band = "Developing"
# elif score < 90:
#     band = "Strong"
# else:
#     band = "Excellent"
#
# print("Output Band:", band)
